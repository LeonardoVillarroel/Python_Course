# %%
#import pylab
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib
from bs4 import BeautifulSoup as bs
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests

# %%
# Get page with all OPEC speeches from 2021 

page = requests.get('https://www.opec.org/opec_web/en/press_room/6297.htm')


URL2021 =  'https://www.opec.org/opec_web/en/press_room/6297.htm'+str(page)

# %%
# Get  the html code as an object

soup = bs(page.text,'lxml')
print(type(soup))
page.text[0:100000]
# Out:
# <class 'bs4.BeautifulSoup'>
# ...

# %%
#Filter the HTML code to get the specific tags to the speeches links
tags = []
for tag in soup.findAll('a', attrs={'href': re.compile("^/opec_web/en/press_room/6")}):
    tags.append(tag)
    print(HTML_speeches)
filtered = soup.find_all('a', {'href': re.compile(r'crummy\.com/')})
print(filtered)
# Out:
# [<a href="/opec_web/en/press_room/6753.htm">Keynote address by OPEC Secretary General</a>]
# [<a href="/opec_web/en/press_room/6753.htm">Keynote address by OPEC Secretary General</a>, <a href="/opec_web/en/press_room/6746.htm">Opening remarks by OPEC Secretary General</a>]
# [<a href="/opec_web/en/press_room/6753.htm">Keynote address by OPEC Secretary General</a>, <a href="/opec_web/en/press_room/6746.htm">Opening remarks by OPEC Secretary General</a>, <a href="/opec_web/en/press_room/6704.htm">OPEC Statement to the UN Climate Change Conference (COP 26/CMP 16/CMA 3)</a>]
# [<a href="/opec_web/en/press_room/6753.htm">Keynote address by OPEC Secretary General</a>, <a href="/opec_web/en/press_room/6746.htm">Opening remarks by OPEC Secretary General</a>, <a href="/opec_web/en/press_room/6704.htm">OPEC Statement to the UN Climate Change Conference (COP 26/CMP 16/CMA 3)</a>, <a href="/opec_web/en/press_room/6697.htm">Opening keynote address by OPEC Secretary General</a>]
# ...

# %%
#Getting the links from the tags
links = []
for link in soup.findAll('a', attrs={'href': re.compile("^/opec_web/en/press_room/6")}):
    links.append(link.get('href'))
links
# Out:
# ['/opec_web/en/press_room/6753.htm',
#  '/opec_web/en/press_room/6746.htm',
#  '/opec_web/en/press_room/6704.htm',
#  '/opec_web/en/press_room/6697.htm',
#  '/opec_web/en/press_room/6640.htm',
#  '/opec_web/en/press_room/6638.htm',
#  '/opec_web/en/press_room/6497.htm',
#  '/opec_web/en/press_room/6484.htm',
#  '/opec_web/en/press_room/6449.htm',
#  '/opec_web/en/press_room/6416.htm',
#  '/opec_web/en/press_room/6406.htm',
#  '/opec_web/en/press_room/6405.htm',
#  '/opec_web/en/press_room/6404.htm',
#  '/opec_web/en/press_room/6401.htm',
#  '/opec_web/en/press_room/6393.htm',
#  '/opec_web/en/press_room/6363.htm',
#  '/opec_web/en/press_room/6335.htm',
#  '/opec_web/en/press_room/6307.htm',
#  '/opec_web/en/press_room/6305.htm',
#  '/opec_web/en/press_room/6295.htm']
